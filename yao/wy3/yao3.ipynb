# %%
import os
import sys

# %%
home = os.environ['HOME']
work_path = os.path.join(home, 'far/farMe/yao/wy3')
src_path = os.path.join(home, 'far/PHARE')
build_path = os.path.join(home, 'far/builds/release/master')

# %%
sys.path.append(os.path.join(src_path, "pyphare"))

# %%
import subprocess
import pyphare
import matplotlib.pyplot as plt
from pyphare.pharesee.run import Run
from pyphare.core.operators import dot, cross, sqrt, modulus, grad
# from pyphare.core.ufuncs import gF, peakIds
import numpy as np
from numpy import polyfit

# %%
run_name = "w3a"

# %%
run_path = os.path.join(work_path, run_name)

# %%
if os.path.isdir(run_path):
    files = os.listdir(run_path)
else:
    files = []

# %%
if 'PYTHONPATH' in os.environ:
    os.environ['PYTHONPATH'] += os.pathsep + os.path.join(src_path, "pyphare")
else:
    os.environ['PYTHONPATH'] = os.pathsep + os.path.join(src_path, "pyphare")
os.environ['PYTHONPATH'] += os.pathsep + build_path

# %%
if 'EM_E.h5' not in files :
    os.chdir(work_path)
    subprocess.run(['mpirun', '-n', '6', '/usr/bin/python3', work_path+'/yao3.py', ], env=os.environ)
# Out:
# validating dim=2
# 2d periodic validation
# validating dim=2
# validating dim=2
# validating direction ... 0
# direction 0 is periodic?
# 2d periodic validation
# 2d periodic validation
# validating direction ... 0
# validating direction ... 0
# direction 0 is periodic?
# direction 0 is periodic?
# validating dim=2
# 2d periodic validation
# validating direction ... 0
# direction 0 is periodic?
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# validating dim=2
# 2d periodic validation
# validating direction ... 0
# direction 0 is periodic?
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7f956b201100>)
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7f604d800dc0>)
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7fbfe3864c40>)
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7fee23865600>)
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7f7b2e064d00>)
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# validating dim=2
# 2d periodic validation
# validating direction ... 0
# direction 0 is periodic?
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# validating direction ... 1
# direction 1 is periodic?
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = [0. 0. 0. 0.] and fR = [0. 0. 0. 0.] and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthy : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vthz : fL = 0.4472135954999579 and fR = 0.4472135954999579 and check = True
# checked vx : fL = 0.0 and fR = 0.0 and check = True
# checked vy : fL = 0.0 and fR = 0.0 and check = True
# checked vz : fL = 0.0 and fR = 0.0 and check = True
# checked vthx : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthy : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# checked vthz : fL = 0.31622776601683794 and fR = 0.31622776601683794 and check = True
# Exception caught in "Simulator.setup()": (<class 'ModuleNotFoundError'>, ModuleNotFoundError("No module named 'pybindlibs'"), <traceback object at 0x7fa491000c80>)
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# Exception caught in "Simulator.initialize()": <class 'ValueError'>
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 138, in initialize
#     self.setup()
#     ~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 131, in setup
#     raise ValueError("Error in Simulator.setup(), see previous error")
# ValueError: Error in Simulator.setup(), see previous error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 257, in <module>
#     main()
#     ~~~~^^
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 252, in main
#     sim.initialize()
#     ~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 154, in initialize
#     raise ValueError("Error in Simulator.initialize(), see previous error")
# ValueError: Error in Simulator.initialize(), see previous error
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 138, in initialize
#     self.setup()
#     ~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 131, in setup
#     raise ValueError("Error in Simulator.setup(), see previous error")
# ValueError: Error in Simulator.setup(), see previous error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 257, in <module>
#     main()
#     ~~~~^^
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 252, in main
#     sim.initialize()
#     ~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 154, in initialize
#     raise ValueError("Error in Simulator.initialize(), see previous error")
# ValueError: Error in Simulator.initialize(), see previous error
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 138, in initialize
#     self.setup()
#     ~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 131, in setup
#     raise ValueError("Error in Simulator.setup(), see previous error")
# ValueError: Error in Simulator.setup(), see previous error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 257, in <module>
#     main()
#     ~~~~^^
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 252, in main
#     sim.initialize()
#     ~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 154, in initialize
#     raise ValueError("Error in Simulator.initialize(), see previous error")
# ValueError: Error in Simulator.initialize(), see previous error
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# ModuleNotFoundError: No module named 'pybindlibs'
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 110, in setup
#     startMPI()
#     ~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 45, in startMPI
#     life_cycles["samrai"] = cpp.cpp_etc_lib().SamraiLifeCycle()
#                             ~~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/cpp/__init__.py", line 28, in cpp_etc_lib
#     return importlib.import_module("pybindlibs.cpp_etc")
#            ~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib64/python3.13/importlib/__init__.py", line 88, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#
# During handling of the above exception, another exception occurred:
#
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1310, in _find_and_load_unlocked
#   File "<frozen importlib._bootstrap>", line 488, in _call_with_frames_removed
#   File "<frozen importlib._bootstrap>", line 1387, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1360, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1324, in _find_and_load_unlocked
# Traceback (most recent call last):
# ModuleNotFoundError: No module named 'pybindlibs'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 138, in initialize
#     self.setup()
#     ~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 131, in setup
#     raise ValueError("Error in Simulator.setup(), see previous error")
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 138, in initialize
#     self.setup()
#     ~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 131, in setup
#     raise ValueError("Error in Simulator.setup(), see previous error")
# ValueError: Error in Simulator.setup(), see previous error
# ValueError: Error in Simulator.setup(), see previous error
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 257, in <module>
#     main()
#     ~~~~^^
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 252, in main
#     sim.initialize()
#     ~~~~~~~~~~~~~~^^
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 154, in initialize
#     raise ValueError("Error in Simulator.initialize(), see previous error")
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 257, in <module>
#     main()
#     ~~~~^^
#   File "/home/smets/far/farMe/yao/wy3/yao3.py", line 252, in main
#     sim.initialize()
#     ~~~~~~~~~~~~~~^^
# ValueError: Error in Simulator.initialize(), see previous error
#   File "/home/smets/far/PHARE/pyphare/pyphare/simulator/simulator.py", line 154, in initialize
#     raise ValueError("Error in Simulator.initialize(), see previous error")
# ValueError: Error in Simulator.initialize(), see previous error
# --------------------------------------------------------------------------
# prterun detected that one or more processes exited with non-zero status,
# thus causing the job to be terminated. The first process to do so was:
#
#    Process name: [prterun-krusty-28737@1,1] Exit code:    1
# --------------------------------------------------------------------------

# %%
import sys
sys.path.append("/home/weipeng/phare_venv/PHARE/pyphare")
import os
import subprocess
import pyphare
import matplotlib.pyplot as plt
from pyphare.pharesee.run import Run
from pyphare.core.operators import dot, cross, sqrt, modulus, grad
import numpy as np

# %%
import scienceplots as splt

plt.style.use(["nature", "notebook", "grid", "high-vis"])

plt.rc("text", usetex=False)
plt.rc("xtick", labelsize=14)
plt.rc("ytick", labelsize=14)
plt.rc("axes", labelsize=14)
plt.rc("legend", fontsize=12)

# %%
run_path = "/scratch/weipeng/Data_phare/ds_t1/" # here you put the path to the data folder
os.listdir(run_path)

# %%
run  = Run(run_path)

# %%
time = 3.0

# %%
main = run.GetParticles(time,"s1") # you can use "s1, "s2" (both not working) and "amb" (working)

# %%
fig, ax = plt.subplots(figsize=(10,4))

main.dist_plot(
                axis=("x", "Vx"),
                ax=ax,
                bins=(500,500),
                # norm=0.4,
                # finest=True,
                # gaussian_filter_sigma=(1, 1),
                # vmin=vmin,
                # vmax=vmax,
                # dv=0.05,
                ymin=-6,ymax=6,
                title="t = {:.1f}".format(time),
                # xlabel="",
                # ylabel="",
            )
